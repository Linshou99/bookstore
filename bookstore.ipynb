# %%
import sqlalchemy
from sqlalchemy import Column, String, create_engine, Integer, Text, Date
from sqlalchemy.orm import sessionmaker,scoped_session
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Enum,ForeignKey,UniqueConstraint
from sqlalchemy.orm import relationship

import time
from sqlalchemy import create_engine
engine = create_engine("postgresql://stu10205501429:Stu10205501429@dase-cdms-2022-pub.pg.rds.aliyuncs.com:5432/stu10205501429",echo=True)
Session = sessionmaker(bind=engine)
session = scoped_session(Session)
DbSession = sessionmaker(bind=engine)
session = DbSession()

# %%
Base = declarative_base()
class User(Base):
            # 表的名字:
    __tablename__ = 'user'    
            # 表的结构:
    user_id = Column(Text, primary_key=True, unique=True, nullable=False)
    password = Column(Text, nullable=False)
    balance = Column(Integer, nullable=False)
    token = Column(Text)
    terminal = Column(Text)
            
class User_Store(Base):
            # 表的名字:
    __tablename__ = 'user_store'
    
            # 表的结构:
    user_id = Column(Text, primary_key=True, nullable=False)
    store_id = Column(Text, primary_key=True, nullable=False)
                
class Store(Base):
            # 表的名字:
    __tablename__ = 'store'

            # 表的结构:
    store_id = Column(Text, primary_key=True, nullable=False)
    book_id = Column(Text, primary_key=True, nullable=False)  
    book_info = Column(Text)
    stock_level = Column(Integer)
            
class New_Order(Base):
            # 表的名字:
    __tablename__ = 'new_order'

            # 表的结构:
    order_id = Column(Text, primary_key=True, nullable=False)
    user_id = Column(Text)  
    store_id = Column(Text)

class New_Order_Detail(Base):
            # 表的名字:
    __tablename__ = 'new_order_detail'
            # 表的结构:
    order_id = Column(Text, primary_key=True, nullable=False)
    book_id = Column(Text, primary_key=True, nullable=False)  
    count = Column(Integer)
    price = Column(Integer)

#def createTable():    # 创建所有继承于Base的类对应的表
 #   Base.metadata.create_all(engine)
    
#createTable()

    # 删除表
Base.metadata.drop_all(engine)
    # 创建表
Session = sessionmaker(bind=engine)
session = scoped_session(Session)
Base.metadata.create_all(engine)
# Out:
# 2022-11-27 15:37:37,671 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-11-27 15:37:37,672 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-27 15:37:37,677 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-11-27 15:37:37,677 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-27 15:37:37,683 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-11-27 15:37:37,683 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-27 15:37:37,688 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 15:37:37,689 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,689 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {'name': 'user'}
# 2022-11-27 15:37:37,695 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,696 INFO sqlalchemy.engine.Engine [cached since 0.006947s ago] {'name': 'user_store'}
# 2022-11-27 15:37:37,699 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,699 INFO sqlalchemy.engine.Engine [cached since 0.01042s ago] {'name': 'store'}
# 2022-11-27 15:37:37,702 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,703 INFO sqlalchemy.engine.Engine [cached since 0.01379s ago] {'name': 'new_order'}
# 2022-11-27 15:37:37,706 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,706 INFO sqlalchemy.engine.Engine [cached since 0.01731s ago] {'name': 'new_order_detail'}
# 2022-11-27 15:37:37,709 INFO sqlalchemy.engine.Engine COMMIT
# 2022-11-27 15:37:37,712 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 15:37:37,713 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,713 INFO sqlalchemy.engine.Engine [cached since 0.02412s ago] {'name': 'user'}
# 2022-11-27 15:37:37,718 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,719 INFO sqlalchemy.engine.Engine [cached since 0.02979s ago] {'name': 'user_store'}
# 2022-11-27 15:37:37,722 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,722 INFO sqlalchemy.engine.Engine [cached since 0.03322s ago] {'name': 'store'}
# 2022-11-27 15:37:37,725 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,726 INFO sqlalchemy.engine.Engine [cached since 0.03672s ago] {'name': 'new_order'}
# 2022-11-27 15:37:37,729 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-27 15:37:37,729 INFO sqlalchemy.engine.Engine [cached since 0.04015s ago] {'name': 'new_order_detail'}
# 2022-11-27 15:37:37,733 INFO sqlalchemy.engine.Engine
# CREATE TABLE "user" (
# 	user_id TEXT NOT NULL,
# 	password TEXT NOT NULL,
# 	balance INTEGER NOT NULL,
# 	token TEXT,
# 	terminal TEXT,
# 	PRIMARY KEY (user_id),
# 	UNIQUE (user_id)
# )
#
#
# 2022-11-27 15:37:37,733 INFO sqlalchemy.engine.Engine [no key 0.00038s] {}
# 2022-11-27 15:37:37,740 INFO sqlalchemy.engine.Engine
# CREATE TABLE user_store (
# 	user_id TEXT NOT NULL,
# 	store_id TEXT NOT NULL,
# 	PRIMARY KEY (user_id, store_id)
# )
#
#
# 2022-11-27 15:37:37,740 INFO sqlalchemy.engine.Engine [no key 0.00039s] {}
# 2022-11-27 15:37:37,745 INFO sqlalchemy.engine.Engine
# CREATE TABLE store (
# 	store_id TEXT NOT NULL,
# 	book_id TEXT NOT NULL,
# 	book_info TEXT,
# 	stock_level INTEGER,
# 	PRIMARY KEY (store_id, book_id)
# )
#
#
# 2022-11-27 15:37:37,746 INFO sqlalchemy.engine.Engine [no key 0.00042s] {}
# 2022-11-27 15:37:37,752 INFO sqlalchemy.engine.Engine
# CREATE TABLE new_order (
# 	order_id TEXT NOT NULL,
# 	user_id TEXT,
# 	store_id TEXT,
# 	PRIMARY KEY (order_id)
# )
#
#
# 2022-11-27 15:37:37,752 INFO sqlalchemy.engine.Engine [no key 0.00040s] {}
# 2022-11-27 15:37:37,757 INFO sqlalchemy.engine.Engine
# CREATE TABLE new_order_detail (
# 	order_id TEXT NOT NULL,
# 	book_id TEXT NOT NULL,
# 	count INTEGER,
# 	price INTEGER,
# 	PRIMARY KEY (order_id, book_id)
# )
#
#
# 2022-11-27 15:37:37,757 INFO sqlalchemy.engine.Engine [no key 0.00038s] {}
# 2022-11-27 15:37:37,763 INFO sqlalchemy.engine.Engine COMMIT

# %%
# 插入操作
def insertData():
    
    # 创建会话 
    session = DbSession()
    
    # 创建新User对象:
    new_user = User(user_id='mdotdot', password='女', balance=120,
    token='19981021', terminal='ECNU')
    new_user1 = User(user_id='xdot', password='男', balance=130,
    token='19990110', terminal='ECNU')
    
    # 添加到session:
    session.add(new_user)
    session.add(new_user1)
    # 提交即保存到数据库:
    session.commit()
    
    # 关闭session: 
    session.close()
    
insertData()
# Out:
# 2022-11-27 15:38:35,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 15:38:35,823 INFO sqlalchemy.engine.Engine INSERT INTO "user" (user_id, password, balance, token, terminal) VALUES (%(user_id)s, %(password)s, %(balance)s, %(token)s, %(terminal)s)
# 2022-11-27 15:38:35,823 INFO sqlalchemy.engine.Engine [generated in 0.00056s] ({'user_id': 'mdotdot', 'password': '女', 'balance': 120, 'token': '19981021', 'terminal': 'ECNU'}, {'user_id': 'xdot', 'password': '男', 'balance': 130, 'token': '19990110', 'terminal': 'ECNU'})
# 2022-11-27 15:38:35,829 INFO sqlalchemy.engine.Engine COMMIT

# %%
#查询user所有数据
def find_all():
    # 创建Session
    session = DbSession()
    
    user = session.query(User).all()
    for i in user:
        print('id:',i.user_id)
        print('name:', i.password)
        print('token:', i.token)
        print('balance:', i.balance)
        print('terminal:', i.terminal)
        
    session.close() # 关闭Session
    
find_all()

#查询user_store所有数据
def find_us():
    # 创建Session
    session = DbSession()
    
    user = session.query(User_Store).all()
    for i in user:
        print('id:',i.user_id)
        print('name:', i.password)
        print('token:', i.token)
        print('balance:', i.balance)
        print('terminal:', i.terminal)
        
    session.close() # 关闭Session
    
find_us()
# Out:
# 2022-11-27 17:56:23,665 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 17:56:23,666 INFO sqlalchemy.engine.Engine SELECT "user".user_id AS user_user_id, "user".password AS user_password, "user".balance AS user_balance, "user".token AS user_token, "user".terminal AS user_terminal
# FROM "user"
# 2022-11-27 17:56:23,666 INFO sqlalchemy.engine.Engine [cached since 8261s ago] {}
# id: test_add_books_seller_id_a63941a6-6e39-11ed-b005-dc1ba1aaec7b
# name: test_add_books_seller_id_a63941a6-6e39-11ed-b005-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va3Nfc2VsbGVyX2lkX2E2Mzk0MWE2LTZlMzktMTFlZC1iMDA1LWRjMWJhMWFhZWM3YiIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0MC40NTQ4NDkiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDAuNDU0ODQ5fQ.UEqPn8lpW9Eip374azA0hhY3Zn0ZpsRZlCTd-U0HT0Y
# balance: 0
# terminal: terminal_1669542940.454849
# id: test_add_books_seller_id_a6cb40a5-6e39-11ed-8efd-dc1ba1aaec7b
# name: test_add_books_seller_id_a6cb40a5-6e39-11ed-8efd-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va3Nfc2VsbGVyX2lkX2E2Y2I0MGE1LTZlMzktMTFlZC04ZWZkLWRjMWJhMWFhZWM3YiIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0MC44OTUxODk1IiwidGltZXN0YW1wIjoxNjY5NTQyOTQwLjg5NjE0MjV9.csduERV-yEakHJHvwF4V2WtSwX80aD0pSIPL8HqtIE4
# balance: 0
# terminal: terminal_1669542940.8951895
# id: test_add_books_seller_id_a6dda90b-6e39-11ed-83c6-dc1ba1aaec7b
# name: test_add_books_seller_id_a6dda90b-6e39-11ed-83c6-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va3Nfc2VsbGVyX2lkX2E2ZGRhOTBiLTZlMzktMTFlZC04M2M2LWRjMWJhMWFhZWM3YiIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0MS4wMTI5MSIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0MS4wMTI5MX0.KXRzSXLwvY4gr0GD0sJtL9lYFWGg8ZzuVhA5Yza1EBA
# balance: 0
# terminal: terminal_1669542941.01291
# id: test_add_books_seller_id_a6ed08a7-6e39-11ed-a461-dc1ba1aaec7b
# name: test_add_books_seller_id_a6ed08a7-6e39-11ed-a461-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va3Nfc2VsbGVyX2lkX2E2ZWQwOGE3LTZlMzktMTFlZC1hNDYxLWRjMWJhMWFhZWM3YiIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0MS4xMTM2NzQiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDEuMTEzNjc0fQ.k90sKZV3UtWUXctGKeH02CCly-xJJyzMTRAfP1VLHVg
# balance: 0
# terminal: terminal_1669542941.113674
# id: test_add_funds_a6fbe5b5-6e39-11ed-a2f7-dc1ba1aaec7b
# name: test_add_funds_a6fbe5b5-6e39-11ed-a2f7-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfZnVuZHNfYTZmYmU1YjUtNmUzOS0xMWVkLWEyZjctZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQxLjIxMjAxMzciLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDEuMjEyMDEzN30.fLeopQk15nzvTuUcPtIMyNSvLo0MoYnCUWyOXC7jBhI
# balance: 0
# terminal: terminal_1669542941.2120137
# id: test_add_funds_a76859ce-6e39-11ed-9fef-dc1ba1aaec7b
# name: test_add_funds_a76859ce-6e39-11ed-9fef-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfZnVuZHNfYTc2ODU5Y2UtNmUzOS0xMWVkLTlmZWYtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQxLjkyMzg1NDYiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDEuOTIzODU0Nn0.GJDFBbouGW86vDiLrLsfse2-OkD1K5D9BfeayO6g4Mk
# balance: 0
# terminal: terminal_1669542941.9238546
# id: test_add_funds_a77b0673-6e39-11ed-9cf1-dc1ba1aaec7b
# name: test_add_funds_a77b0673-6e39-11ed-9cf1-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfZnVuZHNfYTc3YjA2NzMtNmUzOS0xMWVkLTljZjEtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQyLjA0MzYzMjciLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDIuMDQzNjMyN30.8oPjyze6ZP0uUo99AtmpAMu2zNtODel2jRnH1ODqkr0
# balance: 0
# terminal: terminal_1669542942.0436327
# id: test_add_book_stock_level1_user_a78af4d6-6e39-11ed-8ba8-dc1ba1aaec7b
# name: test_add_book_stock_level1_user_a78af4d6-6e39-11ed-8ba8-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va19zdG9ja19sZXZlbDFfdXNlcl9hNzhhZjRkNi02ZTM5LTExZWQtOGJhOC1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuMTQ3NjQ5IiwidGltZXN0YW1wIjoxNjY5NTQyOTQyLjE0NzY0OX0.GI9ljF9RNx-5i-wvop1FOEQV5zvYuSktCWWsm_EfjDI
# balance: 0
# terminal: terminal_1669542942.147649
# id: test_add_book_stock_level1_user_a79ad324-6e39-11ed-9130-dc1ba1aaec7b
# name: test_add_book_stock_level1_user_a79ad324-6e39-11ed-9130-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va19zdG9ja19sZXZlbDFfdXNlcl9hNzlhZDMyNC02ZTM5LTExZWQtOTEzMC1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuMjUzMjAxNSIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0Mi4yNTMyMDE1fQ.SpggEHZNZALWtbUs31RGUdu1KCNAz4eKLKmH6ZNGNZ8
# balance: 0
# terminal: terminal_1669542942.2532015
# id: test_add_book_stock_level1_user_a7aaa54c-6e39-11ed-9c10-dc1ba1aaec7b
# name: test_add_book_stock_level1_user_a7aaa54c-6e39-11ed-9c10-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va19zdG9ja19sZXZlbDFfdXNlcl9hN2FhYTU0Yy02ZTM5LTExZWQtOWMxMC1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuMzU3OTYzNiIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0Mi4zNTc5NjM2fQ.UlvhZqGewZldnejQVPxSas45jltwbYg0maeS5vuqN8I
# balance: 0
# terminal: terminal_1669542942.3579636
# id: test_add_book_stock_level1_user_a7ba77d2-6e39-11ed-9b03-dc1ba1aaec7b
# name: test_add_book_stock_level1_user_a7ba77d2-6e39-11ed-9b03-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9hZGRfYm9va19zdG9ja19sZXZlbDFfdXNlcl9hN2JhNzdkMi02ZTM5LTExZWQtOWIwMy1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuNDYxMDA3IiwidGltZXN0YW1wIjoxNjY5NTQyOTQyLjQ2MTAwN30.unt3enD4CCc7OAT6gIDjO5nGB2wax1PYGtDrZXyljZQ
# balance: 0
# terminal: terminal_1669542942.461007
# id: seller_1_a7cad051-6e39-11ed-9fbd-dc1ba1aaec7b
# name: password_seller_1_a7cad051-6e39-11ed-9fbd-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoic2VsbGVyXzFfYTdjYWQwNTEtNmUzOS0xMWVkLTlmYmQtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQyLjU3MDk2NzIiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDIuNTcwOTY3Mn0.4fsaOJ-wtaWL7juQHS_9vgtGqINBOcpH4QglulAyIxw
# balance: 0
# terminal: terminal_1669542942.5709672
# id: test_create_store_user_a7dd8159-6e39-11ed-a58f-dc1ba1aaec7b
# name: test_create_store_user_a7dd8159-6e39-11ed-a58f-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9jcmVhdGVfc3RvcmVfdXNlcl9hN2RkODE1OS02ZTM5LTExZWQtYTU4Zi1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuNjkxNjQyOCIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0Mi42OTE2NDI4fQ.mQlsU1cX3juYbJ7J8KdWi7HroirOTCwS8v8o-dyYFf8
# balance: 0
# terminal: terminal_1669542942.6916428
# id: test_create_store_user_a7ec8a62-6e39-11ed-9e06-dc1ba1aaec7b
# name: test_create_store_user_a7ec8a62-6e39-11ed-9e06-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9jcmVhdGVfc3RvcmVfdXNlcl9hN2VjOGE2Mi02ZTM5LTExZWQtOWUwNi1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuNzg5MTY1IiwidGltZXN0YW1wIjoxNjY5NTQyOTQyLjc4OTE2NX0.BMaX7f4ZTPCHLC__DyvyjlaPjlhlTo1CyUEr-Sw5Gr0
# balance: 0
# terminal: terminal_1669542942.789165
# id: test_login_1669542942.8787682
# name: password_test_login_1669542942.8787682
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9sb2dpbl8xNjY5NTQyOTQyLjg3ODc2ODIiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuODgyNzY4OSIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0Mi44ODI3Njg5fQ.ctPCoVaUmcDBT-LiGZolEWVWGLynL93qdjOMpUNw8zk
# balance: 0
# terminal: terminal_1669542942.8827689
# id: test_login_1669542942.9878867
# name: password_test_login_1669542942.9878867
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9sb2dpbl8xNjY5NTQyOTQyLjk4Nzg4NjciLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDIuOTkxODY2IiwidGltZXN0YW1wIjoxNjY5NTQyOTQyLjk5MTg2Nn0.e06A-PaoNaoZFajYp2kcuB2sHTSSBV5-qh7KfwkymYw
# balance: 0
# terminal: terminal_1669542942.991866
# id: test_login_1669542943.139383
# name: password_test_login_1669542943.139383
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9sb2dpbl8xNjY5NTQyOTQzLjEzOTM4MyIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0My4xNDUzODYyIiwidGltZXN0YW1wIjoxNjY5NTQyOTQzLjE0NTM4NjJ9.OZXK8-KvXr7gp096k5YYGKleU0M8EQugyOdmHGdbS7M
# balance: 0
# terminal: terminal_1669542943.1453862
# id: test_new_order_buyer_id_a83106a2-6e39-11ed-90d8-dc1ba1aaec7b
# name: test_new_order_seller_id_a83106a0-6e39-11ed-8b7f-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9uZXdfb3JkZXJfYnV5ZXJfaWRfYTgzMTA2YTItNmUzOS0xMWVkLTkwZDgtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQzLjIzNzk4OTIiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDMuMjM3OTg5Mn0.KFx_c7ebnBWZQ0uAxwRS4ORpgiefw_BQNj6oFMEJZjY
# balance: 0
# terminal: terminal_1669542943.2379892
# id: test_new_order_buyer_id_a840dfd4-6e39-11ed-958c-dc1ba1aaec7b
# name: test_new_order_seller_id_a840dfd2-6e39-11ed-b8f5-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9uZXdfb3JkZXJfYnV5ZXJfaWRfYTg0MGRmZDQtNmUzOS0xMWVkLTk1OGMtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQzLjM0MTE0NzciLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDMuMzQxMTQ3N30._Iz5LNMiXlEXS3KNIqOOoRIWU8oOApfCXUogAtcqPrI
# balance: 0
# terminal: terminal_1669542943.3411477
# id: test_new_order_buyer_id_a852517f-6e39-11ed-adb8-dc1ba1aaec7b
# name: test_new_order_seller_id_a852517d-6e39-11ed-8a0e-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9uZXdfb3JkZXJfYnV5ZXJfaWRfYTg1MjUxN2YtNmUzOS0xMWVkLWFkYjgtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQzLjQ1NjE4NCIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0My40NTYxODR9.X65tN07ZSviVdmWHY20P1gkTSEwg-JL3pdDe-cMKszY
# balance: 0
# terminal: terminal_1669542943.456184
# id: test_new_order_buyer_id_a8649bb7-6e39-11ed-8210-dc1ba1aaec7b
# name: test_new_order_seller_id_a8649bb5-6e39-11ed-bac1-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9uZXdfb3JkZXJfYnV5ZXJfaWRfYTg2NDliYjctNmUzOS0xMWVkLTgyMTAtZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQzLjU3NTExNjQiLCJ0aW1lc3RhbXAiOjE2Njk1NDI5NDMuNTc1MTE2NH0.yDMbqirOyibyvGiYTI0n9vYkXZ9lKgfdKspbhyit7sg
# balance: 0
# terminal: terminal_1669542943.5751164
# id: test_new_order_buyer_id_a876d4ec-6e39-11ed-9f59-dc1ba1aaec7b
# name: test_new_order_seller_id_a876d4ea-6e39-11ed-acc8-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9uZXdfb3JkZXJfYnV5ZXJfaWRfYTg3NmQ0ZWMtNmUzOS0xMWVkLTlmNTktZGMxYmExYWFlYzdiIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQzLjY5NTAyNSIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0My42OTUwMjV9.tlHTM3yeixI0L7rj9i4LVdvUh2_T4LBRqL33PEb7qn8
# balance: 0
# terminal: terminal_1669542943.695025
# id: test_password_a889103a-6e39-11ed-b005-dc1ba1aaec7b
# name: old_password_test_password_a889103a-6e39-11ed-b005-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXNzd29yZF9hODg5MTAzYS02ZTM5LTExZWQtYjAwNS1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDMuODEzOTUxNyIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0My44MTM5NTE3fQ.A0IxHV7cuzuZuwsk0zlfISzSoE4Ia53dE5lM2uftdSo
# balance: 0
# terminal: terminal_1669542943.8139517
# id: test_password_a89851b1-6e39-11ed-acb7-dc1ba1aaec7b
# name: old_password_test_password_a89851b1-6e39-11ed-acb7-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXNzd29yZF9hODk4NTFiMS02ZTM5LTExZWQtYWNiNy1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDMuOTE0MTcyNiIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0My45MTQxNzI2fQ.-F7G-ls13l34w5q6wD_9z47Z3xaivQbwqzZ-DCb2bTw
# balance: 0
# terminal: terminal_1669542943.9141726
# id: test_password_a8a798c3-6e39-11ed-ae30-dc1ba1aaec7b
# name: old_password_test_password_a8a798c3-6e39-11ed-ae30-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXNzd29yZF9hOGE3OThjMy02ZTM5LTExZWQtYWUzMC1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDQuMDE0MDU0MyIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC4wMTQwNTQzfQ.MK-K4ws8ixgfzXUKOCtQTKnnJwAT04vLw7oMg7IT9Po
# balance: 0
# terminal: terminal_1669542944.0140543
# id: test_payment_seller_id_a8b9a84c-6e39-11ed-9b11-dc1ba1aaec7b
# name: test_payment_seller_id_a8b9a84c-6e39-11ed-9b11-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXltZW50X3NlbGxlcl9pZF9hOGI5YTg0Yy02ZTM5LTExZWQtOWIxMS1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDQuMTMyNDE5MyIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC4xMzI0MTkzfQ.teMmFOYzBzILyohID_TascfioTyJxYFQwDsLg-6gAfs
# balance: 0
# terminal: terminal_1669542944.1324193
# id: test_payment_seller_id_a8ca23f4-6e39-11ed-9267-dc1ba1aaec7b
# name: test_payment_seller_id_a8ca23f4-6e39-11ed-9267-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXltZW50X3NlbGxlcl9pZF9hOGNhMjNmNC02ZTM5LTExZWQtOTI2Ny1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDQuMjQwNDM5NCIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC4yNDA0Mzk0fQ.hfrgckp5OMlhMVUjsEhgvRAl73-UAe4IkdUYQqFhtOQ
# balance: 0
# terminal: terminal_1669542944.2404394
# id: test_payment_seller_id_a8dcfc2b-6e39-11ed-a651-dc1ba1aaec7b
# name: test_payment_seller_id_a8dcfc2b-6e39-11ed-a651-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXltZW50X3NlbGxlcl9pZF9hOGRjZmMyYi02ZTM5LTExZWQtYTY1MS1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDQuMzY0NDk4NiIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC4zNjQ0OTg2fQ.UoZ_UtgFCDZlPejTIYmQOHLY5gUKlH4r9XOD0bwc04A
# balance: 0
# terminal: terminal_1669542944.3644986
# id: test_payment_seller_id_a8ee1009-6e39-11ed-a927-dc1ba1aaec7b
# name: test_payment_seller_id_a8ee1009-6e39-11ed-a927-dc1ba1aaec7b
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9wYXltZW50X3NlbGxlcl9pZF9hOGVlMTAwOS02ZTM5LTExZWQtYTkyNy1kYzFiYTFhYWVjN2IiLCJ0ZXJtaW5hbCI6InRlcm1pbmFsXzE2Njk1NDI5NDQuNDc1ODYyNyIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC40NzU4NjI3fQ.QrSaobwUGzUZ-8qraFEIymailWI3mnV6kuCV0YwSR-c
# balance: 0
# terminal: terminal_1669542944.4758627
# id: test_register_user_1669542944.562863
# name: test_register_password_1669542944.562863
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9yZWdpc3Rlcl91c2VyXzE2Njk1NDI5NDQuNTYyODYzIiwidGVybWluYWwiOiJ0ZXJtaW5hbF8xNjY5NTQyOTQ0LjU2Njg2MiIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC41NjY4NjJ9.Mt7Bx3nM5_CsfAvGfjBjIEzwa9VP9SbK4cUY__8-nfA
# balance: 0
# terminal: terminal_1669542944.566862
# id: test_register_user_1669542944.6643631
# name: test_register_password_1669542944.6643631
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9yZWdpc3Rlcl91c2VyXzE2Njk1NDI5NDQuNjY0MzYzMSIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0NC42NzA0NiIsInRpbWVzdGFtcCI6MTY2OTU0Mjk0NC42NzA0Nn0.j3dC2Nn-8LB7f5o1Qm5etz7B40leiY-6DV6DcTK-Ioc
# balance: 0
# terminal: terminal_1669542944.67046
# id: test_register_user_1669542944.7647753
# name: test_register_password_1669542944.7647753
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9yZWdpc3Rlcl91c2VyXzE2Njk1NDI5NDQuNzY0Nzc1MyIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0NC43Njk3NjU0IiwidGltZXN0YW1wIjoxNjY5NTQyOTQ0Ljc2OTc2NTR9.cg4KifpOxmOEppyEX1PqkEQdfJ7JkJTkm-MjmbDzADs
# balance: 0
# terminal: terminal_1669542944.7697654
# id: test_register_user_1669542944.8524811
# name: test_register_password_1669542944.8524811
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidGVzdF9yZWdpc3Rlcl91c2VyXzE2Njk1NDI5NDQuODUyNDgxMSIsInRlcm1pbmFsIjoidGVybWluYWxfMTY2OTU0Mjk0NC44NTgyMTQ0IiwidGltZXN0YW1wIjoxNjY5NTQyOTQ0Ljg1ODIxNDR9.0m2sXH4OTfYSu9zJkwTubuYVI0HB84Mv__pyfOm5_fY
# balance: 0
# terminal: terminal_1669542944.8582144
# 2022-11-27 17:56:23,698 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-11-27 17:56:23,704 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 17:56:23,705 INFO sqlalchemy.engine.Engine SELECT user_store.user_id AS user_store_user_id, user_store.store_id AS user_store_store_id
# FROM user_store
# 2022-11-27 17:56:23,705 INFO sqlalchemy.engine.Engine [cached since 8239s ago] {}
# 2022-11-27 17:56:23,711 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# all tables are deleted
Base.metadata.drop_all(engine)
